# %% [markdown]
# # 03 Model Evaluation
# Compare static, statistical, ML, and hybrid detectors.

# %%
import pandas as pd, json
from pathlib import Path

results = pd.read_csv('../data/processed/anomaly_results.csv')
results['timestamp']=pd.to_datetime(results['timestamp'])
comparison = json.loads(Path('../data/processed/model_comparison.json').read_text())
comparison

# %%
results[['pred_static','pred_statistical','pred_ml','pred_hybrid','anomaly_label']].head()
